# %% [markdown]
# <a href="https://colab.research.google.com/github/Dovila-hub/Dovila-hub/blob/main/nlp_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **NLP PROJECT SUPERVISED LEARNING**

# %% [markdown]
# The first we are going to be focusing on will be Data Exploration and then we are going to merge all 35 files (concatenate) so as to do spelling correction etc...

# %% [markdown]
# ### **DATA CLEANING & EXPLORATION**

# %% [markdown]
# IMPORT ALL NECESSARY LIBRAIRES FOR THE PROJECT.

# %%
import pandas as pd
import numpy as np
import glob
import os
import re

# %% [markdown]
# Import the data from google colbad and then merge so as to be used.

# %%
from google.colab import drive
drive.mount('/content/drive')
folder_path = "/content/drive/MyDrive/Traduction"
# Out:
# Mounted at /content/drive
